# %%
#PSQ2 July 31st - Pandas Movie reccomender practice.

# %%
pwd
# Out:
# 'C:\\Users\\ABC\\3. Edureka\\10. Movies Reccomender'

# %%
import os
import pandas as pd, numpy as np

# %%
os.chdir('C:\\Users\\ABC\\6. Datasets')

# %%
df1 = pd.read_csv('Movie reccomender Movie_Titles_Id1.csv',names=['movieid', 'title'])
df2 = pd.read_csv('Movie reccomender Recommend1.csv', names=['movieid', 'userid', 'ratings','timestamp'])

# %%
df1
# Out:
#       movieid                                      title
# 0           1                           Toy Story (1995)
# 1           2                           GoldenEye (1995)
# 2           3                          Four Rooms (1995)
# 3           4                          Get Shorty (1995)
# 4           5                             Copycat (1995)
# ...       ...                                        ...
# 1677     1678                          Mat' i syn (1997)
# 1678     1679                           B. Monkey (1998)
# 1679     1680                       Sliding Doors (1998)
# 1680     1681                        You So Crazy (1994)
# 1681     1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
df3 = pd.merge(df1,df2,on='movieid')
df3
# Out:
#        movieid               title  userid  ratings  timestamp
# 0            1    Toy Story (1995)      61        4  878542420
# 1            1    Toy Story (1995)     189        3  888732928
# 2            1    Toy Story (1995)      33        4  878542699
# 3            1    Toy Story (1995)     160        4  875072547
# 4            1    Toy Story (1995)      20        4  887431883
# ...        ...                 ...     ...      ...        ...
# 99995      943  Killing Zoe (1994)     415        1  888640027
# 99996      943  Killing Zoe (1994)     219        4  888639575
# 99997      943  Killing Zoe (1994)     796        3  888640311
# 99998      943  Killing Zoe (1994)     739        4  888639929
# 99999      943  Killing Zoe (1994)     391        2  888640291
#
# [100000 rows x 5 columns]

# %%
df4 = df3.groupby('title')
df4.get_group('Killing Zoe (1994)')['ratings'].mean()
# Out:
# 3.4107142857142856

# %%
df3['title'].nunique()
# Out:
# 935

# %%
df3['title'].unique()
# Out:
# array(['Toy Story (1995)', 'GoldenEye (1995)', 'Four Rooms (1995)',
#        'Get Shorty (1995)', 'Copycat (1995)',
#        'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)',
#        'Twelve Monkeys (1995)', 'Babe (1995)', 'Dead Man Walking (1995)',
#        'Richard III (1995)', 'Seven (Se7en) (1995)',
#        'Usual Suspects, The (1995)', 'Mighty Aphrodite (1995)',
#        'Postino, Il (1994)', "Mr. Holland's Opus (1995)",
#        'French Twist (Gazon maudit) (1995)', 'From Dusk Till Dawn (1996)',
#        'White Balloon, The (1995)', "Antonia's Line (1995)",
#        'Angels and Insects (1995)', 'Muppet Treasure Island (1996)',
#        'Braveheart (1995)', 'Taxi Driver (1976)',
#        'Rumble in the Bronx (1995)', 'Birdcage, The (1996)',
#        'Brothers McMullen, The (1995)', 'Bad Boys (1995)',
#        'Apollo 13 (1995)', 'Batman Forever (1995)',
#        'Belle de jour (1967)', 'Crimson Tide (1995)', 'Crumb (1994)',
# ...

# %%
grp = pd.DataFrame(df3.groupby('title')['ratings'].mean())
grp.corr(grp2)

# %%
grp2 = grp.get_group('Exotica (1994)')['ratings'].mean()

# %%
# Out:
#        movieid               title  userid  ratings  timestamp
# 0            1    Toy Story (1995)      61        4  878542420
# 1            1    Toy Story (1995)     189        3  888732928
# 2            1    Toy Story (1995)      33        4  878542699
# 3            1    Toy Story (1995)     160        4  875072547
# 4            1    Toy Story (1995)      20        4  887431883
# ...        ...                 ...     ...      ...        ...
# 99995      943  Killing Zoe (1994)     415        1  888640027
# 99996      943  Killing Zoe (1994)     219        4  888639575
# 99997      943  Killing Zoe (1994)     796        3  888640311
# 99998      943  Killing Zoe (1994)     739        4  888639929
# 99999      943  Killing Zoe (1994)     391        2  888640291
#
# [100000 rows x 5 columns]

# %%
listy1 = []
listy2 = []
for i in df3['title'].unique():
    listy1.append(i)
    listy2.append(df4.get_group(i)['ratings'].mean())
df5 = pd.DataFrame(listy2, listy1, columns=['ratings']) #COOOL TABLE! 
df5.reset_index()
# Out:
#                                     index   ratings
# 0                        Toy Story (1995)  3.610294
# 1                        GoldenEye (1995)  3.709677
# 2                       Four Rooms (1995)  2.796296
# 3                       Get Shorty (1995)  4.333333
# 4                          Copycat (1995)  2.874286
# ..                                    ...       ...
# 930            Murder in the First (1995)  4.265306
# 931                       Airheads (1994)  3.457944
# 932                    With Honors (1994)  4.045455
# 933  What's Love Got to Do with It (1993)  4.265823
# 934                    Killing Zoe (1994)  3.410714
#
# [935 rows x 2 columns]

# %%
grp2
# Out:
# 4.111111111111111

# %%
listy3 = []
listy4 = []
listy5 = []
for i in df3['title'].unique():
    listy3.append(i)
    listy4.append(df4.get_group(i)['ratings'].mean())
for j in df3['movieid'].unique():
    listy5.append(j)
a = np.array(listy3)
b = np.array(listy4)
c = np.array(listy5)
df6 = pd.DataFrame(c, b, a)
df6

# %%
listy3

# %%
star_wars =

# %%
df3
# Out:
#        movieid               title  userid  ratings  timestamp
# 0            1    Toy Story (1995)      61        4  878542420
# 1            1    Toy Story (1995)     189        3  888732928
# 2            1    Toy Story (1995)      33        4  878542699
# 3            1    Toy Story (1995)     160        4  875072547
# 4            1    Toy Story (1995)      20        4  887431883
# ...        ...                 ...     ...      ...        ...
# 99995      943  Killing Zoe (1994)     415        1  888640027
# 99996      943  Killing Zoe (1994)     219        4  888639575
# 99997      943  Killing Zoe (1994)     796        3  888640311
# 99998      943  Killing Zoe (1994)     739        4  888639929
# 99999      943  Killing Zoe (1994)     391        2  888640291
#
# [100000 rows x 5 columns]

# %%
pvt = df3.pivot_table(columns='title', index = 'userid', values = 'ratings')

# %%
pvt.head(5)
# Out:
# title   101 Dalmatians (1996)  12 Angry Men (1957)  187 (1997)  \
# userid
# 1                         NaN                  4.0         5.0
# 2                         NaN                  4.0         NaN
# 3                         NaN                  NaN         NaN
# 4                         NaN                  NaN         NaN
# 5                         NaN                  NaN         NaN
#
# title   20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# userid
# 1                                       3.0                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
# 5                                       NaN                           3.0
#
# title   3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# userid
# ...

# %%
pvt.columns
# Out:
# Index(['101 Dalmatians (1996)', '12 Angry Men (1957)', '187 (1997)',
#        '20,000 Leagues Under the Sea (1954)', '2001: A Space Odyssey (1968)',
#        '3 Ninjas: High Noon At Mega Mountain (1998)', '39 Steps, The (1935)',
#        'Absolute Power (1997)', 'Abyss, The (1989)',
#        'Ace Ventura: Pet Detective (1994)',
#        ...
#        'Wolf (1994)',
#        'Wonderful, Horrible Life of Leni Riefenstahl, The (1993)',
#        'Wonderland (1997)', 'Wrong Trousers, The (1993)', 'Wyatt Earp (1994)',
#        'Year of the Horse (1997)', 'Young Frankenstein (1974)',
#        'Young Guns (1988)', 'Young Poisoner's Handbook, The (1995)',
#        'unknown'],
#       dtype='object', name='title', length=935)

# %%
tw = pvt['12 Angry Men (1957)']
pd.DataFrame(pvt.corrwith(tw)).sort_values(by = 0 , ascending = False)
# Out:
#                                       0
# title
# 12 Angry Men (1957)            1.000000
# Widows' Peak (1994)            0.887353
# Dangerous Beauty (1998)        0.876250
# Magnificent Seven, The (1954)  0.808995
# Rainmaker, The (1997)          0.730353
# ...                                 ...
# Heavenly Creatures (1994)     -0.484123
# Blown Away (1994)             -0.488597
# Michael (1996)                -0.673820
# Leave It to Beaver (1997)           NaN
# Village of the Damned (1995)        NaN
#
# [935 rows x 1 columns]

# %%
#So it's df.corrwith(series) MOST IMPORTATN TAKEAWAY for the day

# %%
pvt
# Out:
# title   101 Dalmatians (1996)  12 Angry Men (1957)  187 (1997)  \
# userid
# 1                         NaN                  4.0         5.0
# 2                         NaN                  4.0         NaN
# 3                         NaN                  NaN         NaN
# 4                         NaN                  NaN         NaN
# 5                         NaN                  NaN         NaN
# ...                       ...                  ...         ...
# 1678                      NaN                  NaN         NaN
# 1679                      NaN                  NaN         NaN
# 1680                      NaN                  NaN         NaN
# 1681                      NaN                  NaN         NaN
# 1682                      NaN                  NaN         NaN
#
# title   20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# userid
# 1                                       3.0                           NaN
# ...

# %%
df3['Count'] = pd.DataFrame(df3.groupby('title')['ratings'].count())
# Out:
#        movieid               title  userid  ratings  timestamp  Count
# 0            1    Toy Story (1995)      61        4  878542420    NaN
# 1            1    Toy Story (1995)     189        3  888732928    NaN
# 2            1    Toy Story (1995)      33        4  878542699    NaN
# 3            1    Toy Story (1995)     160        4  875072547    NaN
# 4            1    Toy Story (1995)      20        4  887431883    NaN
# ...        ...                 ...     ...      ...        ...    ...
# 99995      943  Killing Zoe (1994)     415        1  888640027    NaN
# 99996      943  Killing Zoe (1994)     219        4  888639575    NaN
# 99997      943  Killing Zoe (1994)     796        3  888640311    NaN
# 99998      943  Killing Zoe (1994)     739        4  888639929    NaN
# 99999      943  Killing Zoe (1994)     391        2  888640291    NaN
#
# [100000 rows x 6 columns]

# %%
ratings = pd.DataFrame(df3.groupby('title')['ratings'].mean())

# %%
ratings['Count'] = pd.DataFrame(df3.groupby('title')['ratings'].count())

# %%
ratings.sort_values(by = 'Count', ascending=False)
# Out:
#                                          ratings  Count
# title
# Mission: Impossible (1996)              1.834464    737
# Stand by Me (1986)                      2.908029    685
# Ulee's Gold (1997)                      3.386095    676
# Mighty Aphrodite (1995)                 3.097484    636
# Star Trek V: The Final Frontier (1989)  3.864815    540
# ...                                          ...    ...
# Andre (1994)                            3.500000     20
# Welcome to the Dollhouse (1995)         3.350000     20
# Hunchback of Notre Dame, The (1996)     3.600000     20
# Crying Game, The (1992)                 3.100000     20
# Michael (1996)                          2.700000     20
#
# [935 rows x 2 columns]

# %%
ratings.reset_index(inplace = True)

# %%
pvt['Stand by Me (1986)']
# Out:
# userid
# 1       2.0
# 2       3.0
# 3       NaN
# 4       2.0
# 5       2.0
#        ...
# 1678    NaN
# 1679    NaN
# 1680    NaN
# 1681    NaN
# 1682    NaN
# Name: Stand by Me (1986), Length: 1682, dtype: float64

# %%
#Mve recomender basis ratings of 'x' number of people 
df6 = pvt.corrwith(pvt['Mission: Impossible (1996)']).sort_values(ascending = False)
# Out:
# C:\Users\ABC\anaconda3\lib\site-packages\numpy\lib\function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\ABC\anaconda3\lib\site-packages\numpy\lib\function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
df6.head(50)
# Out:
# title
# Beyond Bedlam (1993)                     1.000000
# Fantasia (1940)                          1.000000
# Fog, The (1980)                          1.000000
# Forbidden Planet (1956)                  1.000000
# Mirror Has Two Faces, The (1996)         1.000000
# Hellraiser: Bloodline (1996)             1.000000
# Andre (1994)                             1.000000
# Mission: Impossible (1996)               1.000000
# Critical Care (1997)                     1.000000
# Traveller (1997)                         1.000000
# Birds, The (1963)                        0.972272
# Braindead (1992)                         0.970725
# Abyss, The (1989)                        0.970725
# Wild Bunch, The (1969)                   0.970725
# Lost Highway (1997)                      0.968496
# Die Hard: With a Vengeance (1995)        0.968246
# Bananas (1971)                           0.960769
# While You Were Sleeping (1995)           0.952579
# Cinderella (1950)                        0.944911
# ...

# %%
ratings['Count'].isna().sum()
# Out:
# 0

# %%
pvt.replace(np.nan, 0, inplace = True)

# %%
pvt['Body Snatchers (1993)'].corr(pvt['101 Dalmatians (1996)']) 
#You cant add 0 in the values it'll fuck up badly the whole code IT HAS TO BE NaN values
# Out:
# 0.4217226985664351

# %%
pvt.corrwith(pvt['101 Dalmatians (1996)'])
# Out:
# title
# 101 Dalmatians (1996)                    1.000000
# 12 Angry Men (1957)                      0.164365
# 187 (1997)                               0.209390
# 20,000 Leagues Under the Sea (1954)      0.017549
# 2001: A Space Odyssey (1968)             0.072521
#                                            ...
# Year of the Horse (1997)                 0.022338
# Young Frankenstein (1974)                0.030150
# Young Guns (1988)                        0.153503
# Young Poisoner's Handbook, The (1995)   -0.014249
# unknown                                  0.075786
# Length: 935, dtype: float64

# %%
for i in ratings['title']:
    pvt.corrwith(pvt[i]) #not working :( )

# %%
for i in ratings['title']:
    df7 = pvt.corrwith(pvt[i]).sort_values(ascending = False) 
    #BASIC SMART ALGO !!
    #The way it works is - pandas will only run the algo on non missing rows. But how does that makes
    #sense unless the same user has oen it ie on mission values. 
    EG: 
    """
    data = {
    'Mission: Impossible (1996)': [5, 4, np.nan, 3, 4],
    'Movie A': [4, np.nan, 3, 4, 5],
    'Movie B': [3, 2, 1, np.nan, 5]
    Mission: Impossible (1996)' and 'Movie A':

Only the rows where both columns have non-missing values are considered: rows 0, 3, and 4.
Mission: Impossible (1996): [5, 3, 4]
Movie A: [4, 4, 5]
    """

#Only if the same user has rated x different movies only then it matters
#SO criteria to run the corrwith is - non missing values !!!

# %%
pvt['Body Snatchers (1993)'].corr(pvt['101 Dalmatians (1996)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13420\4268122191.py in <module>
# ----> 1 pvt['Body Snatchers (1993)'].corr(pvt['101 Dalmatians (1996)']).shape()
#
# TypeError: 'tuple' object is not callable

# %%
df6 = pvt.corrwith(pvt['Mission: Impossible (1996)']).sort_values(ascending = False)

# %%
pvt.corrwith(pvt['101 Dalmatians (1996)']).sort_values(ascending = False)
# Out:
# title
# 101 Dalmatians (1996)                     1.000000
# Body Snatchers (1993)                     0.309337
# Corrina, Corrina (1994)                   0.308650
# Transformers: The Movie, The (1986)       0.290489
# Fallen (1998)                             0.289871
#                                             ...
# Alien (1979)                             -0.021598
# Farinelli: il castrato (1994)            -0.021769
# Monty Python and the Holy Grail (1974)   -0.023896
# Devil in a Blue Dress (1995)             -0.024471
# Little Odessa (1994)                     -0.031353
# Length: 935, dtype: float64

# %%
pvt2 = pvt[['101 Dalmatians (1996)', '12 Angry Men (1957)']].dropna()

# %%
pvt2 
#As you can see the user id and the movie name has to match ie the user has to have rated both movies only then it works
# Out:
# title   101 Dalmatians (1996)  12 Angry Men (1957)
# userid
# 22                        5.0                  5.0
# 64                        4.0                  5.0
# 98                        5.0                  5.0
# 143                       2.0                  4.0
# 172                       5.0                  4.0
# 193                       4.0                  4.0
# 194                       5.0                  4.0
# 215                       5.0                  5.0
# 237                       5.0                  4.0
# 245                       2.0                  3.0
# 286                       4.0                  3.0
# 427                       5.0                  5.0
# 478                       5.0                  5.0
# 480                       5.0                  3.0
# 510                       5.0                  4.0
# 566                       4.0                  4.0

# %%
#I did this to see the number f users that have rated multiple movies as only then will it even be
#considered
df3.sort_values(by = 'userid', ascending = True).tail(50)
# Out:
#        movieid                                              title  userid  \
# 72025      655                                 Stand by Me (1986)    1644
# 72506      655                                 Stand by Me (1986)    1645
# 72330      655                                 Stand by Me (1986)    1646
# 87683      828                                      Alaska (1996)    1646
# 72150      655                                 Stand by Me (1986)    1647
# 72310      655                                 Stand by Me (1986)    1648
# 71959      655                                 Stand by Me (1986)    1649
# 72074      655                                 Stand by Me (1986)    1650
# 71895      655                                 Stand by Me (1986)    1651
# 83583      782                               Little Odessa (1994)    1652
# 73222      662                           Somewhere in Time (1980)    1652
# 81342      756                 Father of the Bride Part II (1995)    1652
# ...
